# %%
#@title Install the required packages
# !pip install

# %%
#@title Code for the basic function1
print("hello")
# Out:
# hello

# %%
#@title Code for the basic function2
print("hello")
# Out:
# 3 5 6

# %%
#@title Code for Image generation
print("images generated")
# Out:
# Images generated
