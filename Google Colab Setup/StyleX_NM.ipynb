# %%
#Clone the main branch of the repo
# !git clone https://github.com/sjasthi/StyleX.git
# Out:
# Cloning into 'StyleX'...
# remote: Enumerating objects: 235, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 235 (delta 13), reused 2 (delta 2), pack-reused 190 (from 1)
# Receiving objects: 100% (235/235), 14.36 MiB | 21.40 MiB/s, done.
# Resolving deltas: 100% (99/99), done.

# %%
#Change into the StyleX directory
# %cd StyleX
# Out:
# /content/StyleX

# %%
#Install the requirements
# !pip -q install -r requirements.txt

# %%
#Login to huggingface (Make sure you have a token. You might have to check the box that says:  "Read access to contents of all public gated repos you can access")
from huggingface_hub import notebook_login
notebook_login()
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...

# %%
#Mount the Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#Check that the folder can be seen | Make sure the path leads to where you have the images in google drive. This "StyleX_Input_Images/Cyberpunk" could be different for you
# !ls "/content/drive/MyDrive/StyleX_Input_Images/Cyberpunk"
# Out:
# 1e751531-e24d-4fd8-8fb0-88cc547c2b53_1920x1080.jpg
# cyberpunk__1_-scaled-5.jpg
# cyberpunk-2077-1-hour-of-lo-fi-music-and-auto-drive-4k-gamep_cctp.1280.webp
# cyberpunk_2077_phantom_liberty_game_informer_review_header_1.jpg.webp
# Cyberpunk_2077_screen_10.webp
# cyberpunk-2-3.webp
# iE4FXnNnPvYsZYc4q9PNiY-1200-80.png

# %%
#Check where you are
# !pwd
# Out:
# /content/StyleX

# %%
# Removes any existing  input_images folder (So you can use the Google Drive one)
# !rm -rf input_images

# %%
#Create a symlink (This is a shortcut that points to another folder or file)
# !ln -s "/content/drive/MyDrive/StyleX_Input_Images" input_images

# %%
#Check that the symlink worked
# !ls input_images
# Out:
# Cyberpunk

# %%
#Run the image generation. Make sure you change the style to the style you want to generate in.
# !python -m src.main --prompt " Daytime cyberpunk city, futuristic megacity under bright daylight, towering high-tech skyscrapers, holographic advertisements visible in daylight, city view." --style Cyberpunk --height 512 --width 512 --steps 30 --guidance 4.0  --cpu-offload --no-t5
# Out:
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Using style: Cyberpunk
# Style folder: /content/drive/MyDrive/StyleX_Input_Images/Cyberpunk
# Files in style folder: 8
#  - iE4FXnNnPvYsZYc4q9PNiY-1200-80.png
#  - cyberpunk-2-3.webp
#  - Cyberpunk_2077_screen_10.webp
#  - 1e751531-e24d-4fd8-8fb0-88cc547c2b53_1920x1080.jpg
#  - cyberpunk__1_-scaled-5.jpg
#  - cyberpunk_2077_phantom_liberty_game_informer_review_header_1.jpg.webp
#  - cyberpunk-2077-1-hour-of-lo-fi-music-and-auto-drive-4k-gamep_cctp.1280.webp
#  - .style_keywords_cache.json
# ...
